# %% [markdown]
# Download [austin_weather.csv](https://drive.google.com/uc?export=download&id=10JkPB2hhDmkVUoCGFP6gpoRL1mvx0OPf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('austin_weather.csv')
df.head()
# Out:
#          Date  TempHighF  ...  PrecipitationSumInches               Events
# 0  2013-12-21         74  ...                    0.46  Rain , Thunderstorm
# 1  2013-12-22         56  ...                       0
# 2  2013-12-23         58  ...                       0
# 3  2013-12-24         61  ...                       0
# 4  2013-12-25         58  ...                       T
#
# [5 rows x 21 columns]

# %%
df['HumidityAvgPercent']= pd.to_numeric(df['HumidityAvgPercent'], errors='coerce')
df['WindAvgMPH']=pd.to_numeric(df['WindAvgMPH'], errors='coerce')
df['DewPointAvgF']=pd.to_numeric(df['DewPointAvgF'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1312 non-null   float64
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1317 non-null   float64
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
#  13  VisibilityHighMiles         1319 non-null   object
#  14  VisibilityAvgMiles          1319 non-null   object
#  15  VisibilityLowMiles          1319 non-null   object
#  16  WindHighMPH                 1319 non-null   object
#  17  WindAvgMPH                  1317 non-null   float64
#  18  WindGustMPH                 1319 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 216.5+ KB

# %% [markdown]
# <h2>Soal 1: Visualisasi Scatter Plot Perbandingan Kuantitatif</h2>
#
# Pada tugas kali ini kita akan mengamati nilai DewPointAvg (F) dengan mengamati nilai  HumidityAvg (%), TempAvg (F), dan WindAvg (MPG)
#
# Perhatikan bahwa data kita tidaklah siap untuk di analisis, salah satunya tipe data dari DewPointAvg (F), HumidityAvg (%), dan WindAvg (MPG) adalah object, padahalnya data nya ber isi numeric. maka :
# - Ubahlah tipe data tersebut menjadi tipe data float
#
# Kemudian:
#
# - Kalian tidak akan dengan mudah mengubah tipe data tersebut karena column tersebut mempunyai nilai '-' yang dimana tidak bisa di ubah ke bentuk float, maka replace lah terlebih dahulu data yang bernilai '-' dengan nilai NaN, gunakan method .replace(). baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html
# - Isi nilai nan dengan nilai sebelumnya di row tersebut. gunakan method .fillna() dengan argument method bernilai 'ffill', baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# - Sekarang ubah tipe datanya dengan float, gunakan method .astype(), baca dokumentasi https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
#
# Setelah ini sebagian data siap untuk di jadikan bahan analisis. maka:
#
# Buahlah visualisasi perbandingan kuantitatif scatter plot, sehingga menghasilkan gambar seperti dibawah:
#
# ket:
#
# - colormap adalah 'coolwarm'
# - berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# - berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
#
#
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!

# %%
df.isnull().sum()
# Out:
# Date                          0
# TempHighF                     0
# TempAvgF                      0
# TempLowF                      0
# DewPointHighF                 0
# DewPointAvgF                  7
# DewPointLowF                  0
# HumidityHighPercent           0
# HumidityAvgPercent            2
# HumidityLowPercent            0
# SeaLevelPressureHighInches    0
# SeaLevelPressureAvgInches     0
# SeaLevelPressureLowInches     0
# VisibilityHighMiles           0
# VisibilityAvgMiles            0
# VisibilityLowMiles            0
# WindHighMPH                   0
# WindAvgMPH                    2
# WindGustMPH                   0
# PrecipitationSumInches        0
# Events                        0
# dtype: int64

# %%
df= df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Date                          0
# TempHighF                     0
# TempAvgF                      0
# TempLowF                      0
# DewPointHighF                 0
# DewPointAvgF                  0
# DewPointLowF                  0
# HumidityHighPercent           0
# HumidityAvgPercent            0
# HumidityLowPercent            0
# SeaLevelPressureHighInches    0
# SeaLevelPressureAvgInches     0
# SeaLevelPressureLowInches     0
# VisibilityHighMiles           0
# VisibilityAvgMiles            0
# VisibilityLowMiles            0
# WindHighMPH                   0
# WindAvgMPH                    0
# WindGustMPH                   0
# PrecipitationSumInches        0
# Events                        0
# dtype: int64

# %%
df.astype({'HumidityAvgPercent': 'float64'},{'WindAvgMPH': 'float64'}).dtypes
df.astype({'DewPointAvgF': 'float64'}).dtypes
print(df.dtypes)
# Out:
# Date                           object
# TempHighF                       int64
# TempAvgF                        int64
# TempLowF                        int64
# DewPointHighF                  object
# DewPointAvgF                  float64
# DewPointLowF                   object
# HumidityHighPercent            object
# HumidityAvgPercent            float64
# HumidityLowPercent             object
# SeaLevelPressureHighInches     object
# SeaLevelPressureAvgInches      object
# SeaLevelPressureLowInches      object
# VisibilityHighMiles            object
# VisibilityAvgMiles             object
# VisibilityLowMiles             object
# WindHighMPH                    object
# WindAvgMPH                    float64
# WindGustMPH                    object
# PrecipitationSumInches         object
# Events                         object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid') 
sns.set(style="white", color_codes=True)

# %%
#Your code here to generate visualization
# ket:
# colormap adalah 'coolwarm'
# berikat warna terhadap setiap data poin dengan nilai dari column TempAvgF
# berikan size terhadap setiap data poin dengan nilai dari column WindAvgMPH, kalikan dengan 20 agar size terlihat lebih besar
plt.subplots(figsize = (20, 10))
plt.scatter(df['HumidityAvgPercent'], df['DewPointAvgF'],c=df['TempAvgF'],s=df['WindAvgMPH']*20, cmap='coolwarm')
plt.colorbar()
plt.title('Austin Weather')
plt.xlabel('Humidity Avg %')
plt.ylabel('Dew Point Avg (F)')
# Out:
# Text(0, 0.5, 'Dew Point Avg (F)')

# %% [markdown]
# Expected visualization Output:
#
# ![alt text](https://drive.google.com/uc?id=1Pp5oIc-39mcw2vrw6xgCRM9GsvyRtPI5)

# %% [markdown]
# Berikan pendapat dari insight yang bisa di dapat dari visualisasi perbandingan kuantitatif ini!!!
#
# #### Jawab pada text cell disini
# 1.   Semakin tinggi rata-rata temperatur (Temp Avg) maka semakin tinggi pula rata-rata titik embunnya(Dew Point Avg), dilihat dari semakin merahnya warna temperature, maka semakin tinggi nilai titik embunnya.
# 2.   Rata rata kecepatan angin tidak memiliki pola di grafik, artinya mungkin tidak berkorelasi dengan variabel kelembaban, titik embun dan temperature.
# 3. Rata-rata temperatur mungkin tidak berkorelasi dengan persentase rata-rata kelembaban (Humidity Avg %) karena tidak terlihat adanya perubahan gradien warna dari humidity yang semakin rendah/tinggi, atau dapat dikatakan tidak terbentuk pola antara humidity dengan temperatur

# %% [markdown]
# <h2>Soal 2: Preparing Data</h2>
#
# Manipulasi data di bawah dengan menggroupkan berdasarkan Genre, kemudian ambil rata2 penjualan untuk setiap Region Kecuali Global_Sales berdasarkan kategori Genre.

# %% [markdown]
# Silahkan Download  <a href="https://blog.sanbercode.com/wp-content/uploads/2020/05/vgsales.csv">vgsales.csv</a>

# %%
#yourcode here
df1 = pd.read_csv('vgsales.csv')
df1.head()
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %%
df2=df1.groupby(by='Genre')['NA_Sales','EU_Sales','JP_Sales','Other_Sales'].mean()
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508
# Adventure     0.082271  0.049868  0.040490     0.013072
# Fighting      0.263667  0.119481  0.103007     0.043255
# Misc          0.235906  0.124198  0.061967     0.043312
# Platform      0.504571  0.227573  0.147596     0.058228
# Puzzle        0.212680  0.087251  0.098471     0.021564
# Racing        0.287766  0.190865  0.045388     0.061865
# Role-Playing  0.219946  0.126384  0.236767     0.040060
# Shooter       0.444733  0.239137  0.029221     0.078389
# Simulation    0.211430  0.130773  0.073472     0.036355
# Sports        0.291283  0.160635  0.057702     0.057532
# Strategy      0.100881  0.066579  0.072628     0.016681

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1dR4vthSt22gM_LdfSBZCMIKPL6xd7nVl)

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 3: Perbandingan Kuantitatif Barplot - Grouping Visualisasi Dengan Barplot</h2>
#
# 1. Visualisasikan data yang tadi kita manipulasi, untuk menghasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1A2s9Uy2i471VEYIZqMoVUIlZnVOUc8ha)

# %%
#your code here to generate visualization
df3=df2.transpose()
plt.style.use('seaborn-darkgrid') 
# sns.axes_style("darkgrid")
ax = df3.plot(kind="bar", width=0.8)
fig = ax.get_figure()
fig.set_size_inches(20, 8)
ax.set_xlabel("Region Sales")
ax.set_ylabel("Mean Sales")
ax.set_title('Mean Sales Video Games by Genre', size=20)
plt.legend(bbox_to_anchor=(1.05,1.18), loc="upper right")
ax.set_facecolor('0.9')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# Jawab:
#
# #### Berikan insights yg didapat di text cell ini dari visualisasi yang didapat
# 1. Secara umum, penjualan video games di NA_Sales adalah tertinggi, dengan kontribusi penjualan terbesar dari genre Platform dan Shooter
# 2. Tingkat penjualan video games bergantung dengan daerah, misalkan genre Role_Playing lebih laris di JP_Sales dibanding region lainnya, bahkan melebihi tingkat penjualan NA_Sales
# 3. Genre Adventure & Strategy merupakan genre yang paling tidak disukai, dapat dilihat dari grafik bahwa kedua genre ini memiliki penjualan terendah di semua region

# %% [markdown]
# ---

# %% [markdown]
# <h2>Soal 4: Perbandingan Kuantitatif Barplot - Stack Barplot</h2>
#
# 1. Visualisasikan data yang tadi kita manipulasi, untuk menhasilkan visualisasi seperti di bawah ini
# 2. Tuliskan apa insight yang bisa kamu dapat dari visualisasi tersebut

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1_yis-3aZsEbsk68tpoPHoNlFftaz2GrO)

# %%
#your code here to generate visualization
#your code here to generate visualization
df3=df2.transpose()
# fig, ax = plt.subplots(figsize=(40,10))
plt.style.use('seaborn-darkgrid') 
ax = df3.plot(kind="bar",stacked=True)
fig = ax.get_figure()
fig.set_size_inches(25, 10)
ax.set_xlabel("Region Sales")
ax.set_ylabel("Mean Sales")
ax.set_title('Mean Sales Video Games by Genre')
ax.set_facecolor('0.9')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %% [markdown]
# Jawab:
#
# #### Berikan insights yg didapat di text cell ini dari visualisasi yang didapat

# %% [markdown]
# 1. NA_Sales memiliki penjualan tertinggi secara keseluruhan, disusul EU_Sales, JP_Sales dan terendah Other_Sales
# 2. NA_Sales berkontribusi 50% Penjualan, EU_Sales 25%, JP_Sales 17% dan other sales sekitar 8%, sehingga perusahaan dapat fokus ke penjualan di NA_Sales dan EU_Sales
